# %%
#These ones were made using examples/DIIID-like_ideal_example");
using JLD2, Plots
@load "fmat_frobenius_at_psi.jld2" fmats_frob psi q

# %%
plot(q, abs.(fmats_frob), xlabel="q", ylabel="|det(F)|", title="F Matrix Determinant vs q", yscale=:log10, legend=:false)

# %%
plot(psi, abs.(fmats_frob), xlabel="Psi", ylabel="|det(F)|",
    title="F Matrix Determinant vs Psi", yscale=:log10,
    legend=:false)
